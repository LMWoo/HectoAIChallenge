# %%
import os
import random
import math
import sys

sys.path.append(
    os.path.dirname(os.getcwd())
)

from src.dataset.baselineDataset import get_datasets
from src.dataset.baselineDataset import BaselineDataset, DeleteMisLabelledDataset
from src.utils.utils import seed_everything, project_path, auto_increment_run_suffix, CFG
from src.utils.constant import Optimizers, Models, Augmentations, Transforms

# %%
train_root = os.path.join(project_path(), 'data/train')
test_root = os.path.join(project_path(), 'data/test')
baseline_dataset = BaselineDataset(train_root, transform=None)
delete_mislabelled_dataset = DeleteMisLabelledDataset(train_root, transform=None)

# %%
print(f'Total baseline_dataset image num: {len(baseline_dataset)}, delete_mislabelled_dataset image num: {len(delete_mislabelled_dataset)}')
# Out:
# Total baseline_dataset image num: 33137, delete_mislabelled_dataset image num: 33130

# %%
augmentation_name = "identity_policy"
transforms_name = "policy_transforms"

# %%
# Models.validation(model_name)
# Optimizers.validation(optimizer_name)
Augmentations.validation(augmentation_name)
Transforms.validation(transforms_name)
    
train_dataset, val_dataset, test_dataset, class_names = get_datasets(Augmentations[augmentation_name.upper()].value, Transforms[transforms_name.upper()].value)
# Out:
# Total image num: 33137
# train image num: 26509, valid image num: 6628

# %%
all_val_filenames = [os.path.basename(val_dataset[i][2]) for i in range(len(val_dataset))]

# %%
'7시리즈_F01_2009_2015_0044.jpg' in all_val_filenames[0]
# Out:
# False

# %%
class_names
# Out:
# ['1시리즈_F20_2013_2015',
#  '1시리즈_F20_2016_2019',
#  '1시리즈_F40_2020_2024',
#  '2008_2015_2017',
#  '2시리즈_그란쿠페_F44_2020_2024',
#  '2시리즈_액티브_투어러_F45_2019_2021',
#  '2시리즈_액티브_투어러_U06_2022_2024',
#  '3008_2세대_2018_2023',
#  '3시리즈_E90_2005_2012',
#  '3시리즈_F30_2013_2018',
#  '3시리즈_G20_2019_2022',
#  '3시리즈_G20_2023_2025',
#  '3시리즈_GT_F34_2014_2021',
#  '4시리즈_F32_2014_2020',
#  '4시리즈_G22_2021_2023',
#  '4시리즈_G22_2024_2025',
#  '5008_2세대_2018_2019',
#  '5008_2세대_2021_2024',
#  '5시리즈_F10_2010_2016',
#  '5시리즈_G30_2017_2023',
#  '5시리즈_G60_2024_2025',
#  '5시리즈_GT_F07_2010_2017',
#  '6시리즈_F12_2011_2018',
#  '6시리즈_GT_G32_2018_2020',
#  '6시리즈_GT_G32_2021_2024',
#  '718_박스터_2017_2024',
#  '718_카이맨_2017_2024',
#  '7시리즈_F01_2009_2015',
#  '7시리즈_G11_2016_2018',
#  '7시리즈_G11_2019_2022',
#  '7시리즈_G70_2023_2025',
#  '8시리즈_G15_2020_2024',
#  '911_2003_2019',
#  '911_992_2020_2024',
#  'A4_B9_2016_2019',
#  'A4_B9_2020_2024',
#  'A5_F5_2019_2024',
#  'A6_C8_2019_2025',
#  'A7_2012_2016',
#  'A7_4K_2020_2024',
# ...

# %%
# TRAIN

# 2시리즈_그란쿠페_F44_2020_2024_0042.jpg 위에 천장만 보임
# 2시리즈_액티브_투어러_U06_2022_2024_0004.jpg 뒤에 트렁크

# 3시리즈_F30_2013_2018_0036.jpg 왼쪽 문 열림
# 3시리즈_F30_2013_2018_0069.jpg 차 위에 글씨

# 4시리즈_F32_2014_2020_0027.jpg 차안

# 4시리즈_G22_2024_2025_0031.jpg 차안

# 5시리즈_G60_2024_2025_0010.jpg 차안
# 5시리즈_G60_2024_2025_0056.jpg 차안

# 6시리즈_GT_G32_2018_2020_0018.jpg 사이드 미러

# 7시리즈_F01_2009_2015_0029.jpg 차안

# 그랜드_체로키_WL_2021_2023_0018.jpg 차안

# 그랜드카니발_2006_2010_0021.jpg 이미지가 뒤집어짐

# 그랜저TG_2007_2008_0000.jpg 주위에 자막

# 그랜저TG_2007_2008_0022.jpg 차에 사람 비침

# 그랜저TG_2007_2008_0075.jpg 차가 아예 안보임

# 뉴_체어맨_W_2012_2016_0009.jpg 차가 아예 안보임
# 뉴_체어맨_W_2012_2016_0022.jpg 차가 아예 안보임
# 뉴_체어맨_W_2012_2016_0043.jpg 차가 아예 안보임

# 뉴_카이엔_2011_2018_0065.jpg 차안

# 뉴_A6_2012_2014_0046.jpg 차안

# 뉴_ES300h_2013_2015_0000.jpg 확인 불가

# 뉴_G80_2025_2026_0043.jpg 확인 불가

# 더_기아_레이_EV_2024_2025_0078.jpg 확인 불가

# 디_올뉴그랜저_2023_2025_0039.jpg 잘못된 레이블링

# 디_올뉴코나_2023_2025_0059.jpg 확인 불가

# 레니게이드_2019_2023_0041.jpg 차안

# 레이_2012_2017_0063.jpg 차안

# 레인지로버_4세대_2018_2022_0048.jpg 차안

# 레인지로버_5세대_2023_2024_0030.jpg 차안

# 레인지로버_스포츠_2세대_2018_2022_0014.jpg 차안 

# 레인지로버_스포츠_2세대_2018_2022_0017.jpg 차안

# 마칸_2019_2021_0035.jpg 차안

# 마칸_2022_2024_0052.jpg 확인 필요

# 머스탱_2015_2023_0086.jpg 차안

# 박스터_718_2017_2024_0011.jpg 확인 불가

# 박스터_718_2017_2024_0051.jpg 잘못된 레이블링

# 싼타페_TM_2019_2020_0009.jpg 차안

# 아반떼_MD_2011_2014_0009.jpg 차안

# 아반떼_MD_2011_2014_0081.jpg 확인 불가

# 아반떼_MD_2011_2014_0082.jpg 차안

# 아반떼_N_2022_2023_0035.jpg 잘못된 레이블링

# 아반떼_N_2022_2023_0064.jpg 잘못된 레이블링

# 아베오_2012_2016_0052.jpg 잘못된 레이블링

# 에쿠스_신형_2010_2015_0042.jpg 이미지 회전됨
# 에쿠스_신형_2010_2015_0043.jpg 이미지 회전됨
# 에쿠스_신형_2010_2015_0044.jpg 이미지 회전됨

# 익스플로러_2016_2017_0072.jpg 차안

# 카이엔_PO536_2019_2023_0035.jpg 차안
# 카이엔_PO536_2019_2023_0054.jpg 차안

# 컨티넨탈_GT_3세대_2018_2023_0007.jpg 차안

# 콰트로포르테_2017_2022_0074.jpg 헤드라이트 

# 타이칸_2021_2025_0003.jpg 차안
# 타이칸_2021_2025_0065.jpg 차안

# 티볼리_에어_2016_2019_0047.jpg 천장

# 파나메라_2010_2016_0000.jpg 썬루프
# 파나메라_2010_2016_0036.jpg 차안

# A8_D5_2018_2023_0084.jpg 트렁크

# C_클래스_W204_2008_2015_0068.jpg 차안

# CLS_클래스_C257_2019_2023_0021.jpg 차안

# E_클래스_W212_2010_2016_0069.jpg 차안

# ES300h_7세대_2019_2026_0028.jpg 차안

# G_클래스_W463_2009_2017_0011.jpg 차안

# G_클래스_W463b_2019_2025_0030.jpg 본네트

# GLB_클래스_X247_2020_2023_0008.jpg 차안

# GLE_클래스_W167_2019_2024_0068.jpg 잘못된 레이블링

# GLS_클래스_X167_2020_2024_0013.jpg 차안

# K3_2013_2015_0045.jpg 차안

# K5_3세대_2020_2023_0081.jpg 차안

# Q5_FY_2021_2024_0032.jpg 차안

# Q7_4M_2020_2023_0011.jpg 차안

# Q30_2017_2019_0075.jpg 썬루프

# Q50_2014_2017_0031.jpb 본네트

# RAV4_5세대_2019_2024_0020.jpg 차안

# S_클래스_W223_2021_2025_0008.jpg 차안

# S_클래스_W223_2021_2025_0071.jpg 차안

# SM7_뉴아트_2008_2011_0053.jpg 잘못된 레이블링

# X4_F26_2015_2018_0068.jpg 차안

# X7_G07_2019_2022_0052.jpg 차안

# XF_X260_2016_2020_0023.jpg 썬루프

# TEST 
# 773, 1107, 1163, 1532, 1573, 1770, 1856, 2682, 2718, 2756, 3113, 4169, 4265, 4532, 5114, 6505, 6649, 6924, 7138
